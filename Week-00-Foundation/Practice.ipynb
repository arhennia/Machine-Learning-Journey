# %% [markdown]
# What is Python?
# 1. High-level programming language
# 2. Easy to read and write
# 3. Interpreted language (runs line by line)
# 4. Dynamically typed (no need to mention data type while creating variables)

# %%
name = "Arti"
age = 20
cgpa = 9.78

# %% [markdown]
# Notice:
# No int, float, char, or string keyword.

# %% [markdown]
# Single line

# %%
# This is a comment

# %% [markdown]
# MultiLine

# %%
"""
This is
a multi-line
comment
"""
# Out:
# '\nThis is\na multi-line\ncomment\n'

# %% [markdown]
# Printing Output

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Print Multiple Stuff

# %%
name = "Arti"
age = 20

print(name, age)
# Out:
# Arti 20

# %% [markdown]
# Variables store data

# %%
x = 10
name = "Python"
pi = 3.14

# %% [markdown]
# Variable names (Valid)

# %%
student_name
marks
x

# %% [markdown]
# Variable names (Invalid)

# %%
2name
student-name
class

# %% [markdown]
# Python Data Types

# %%
age = 20            #integers
cgpa = 9.78         #float
name = "Arti"       #string
color = "black"
is_student = True   #boolean
is_failed = False
x = 2 + 3j          #complex

# %%
fruits = ["Apple", "Banana", "Mango"] #Lists (order can be changed)
#access
print(fruits[0])
# Out:
# Apple

# %%
numbers = (10,20,30)            #tuples (order cannot be changed)
colors = {"Red","Blue","Green"} #set (unique values only)
#duplicate values disappear for example
x = {1,2,2,3}
print(x)
# Out:
# {1, 2, 3}

# %%
student = {             #dictionary (Stores data as Key: Value)
    "name":"Arti",
    "age":20,
    "cgpa":9.78
}
print(student["name"])
# Out:
# Arti

# %% [markdown]
# Checking DataType

# %%
x = 10

print(type(x))
# Out:
# <class 'int'>

# %%
print(type(10))
print(type(3.14))
print(type("Hello"))
print(type(True))
print(type([1,2,3]))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>

# %% [markdown]
# Type Conversion

# %%
x = "25" #string
print(int(x)) #int

a = 10 #int
print(float(a)) #deci

num = 20 #int
print(str(num)) #string
# Out:
# 25
# 10.0
# 20

# %% [markdown]
# Taking Input

# %%
name = input("Enter your name please: ")
print(name)

# %% [markdown]
# input always returns a string
# so if u need a particular type then just add the data type before the input like this

# %%
age = int(input("Enter age: "))
cgpa = float(input("Enter CGPA: "))

# %% [markdown]
# Basic Operators

# %%
+
-
*
/
//
%
**

# %%
a = 10
b = 3

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# Comparison

# %%
==
!=
>
<
>=
<=

# %%
print(10 > 5)
# Out:
# True

# %% [markdown]
# Logical

# %%
and
or
not

# %%
print(True and False)
# Out:
# False

# %% [markdown]
# Assignment

# %%
=
+=
-=
*=
/=

# %%
x = 5
x += 2
print(x)
# Out:
# 7

# %% [markdown]
# Strings

# %%
name = "Arti"
len(name)
name.upper()
name.lower()
name.replace("A","R")
name.upper()
# Out:
# 'ARTI'

# %% [markdown]
# String Formatting

# %%
name = "Arti"
print(f"Hello {name}")
# Out:
# Hello Arti

# %% [markdown]
# Indentation

# %% [markdown]
# Python uses indentation instead of {}

# %%
if True:
    print("Hello")

# %% [markdown]
# Basic Math Functions

# %%
abs(-100)
max(1,5,8)
min(2,4,6)
pow(2,3)
round(3.67)
# Out:
# 4

# %% [markdown]
# Importing Libraries

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %% [markdown]
# Useful Shortcuts

# %%
print(type(variable))
len(variable)
help(variable)

# %% [markdown]
# Mini Practice

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
cgpa = float(input("Enter CGPA: "))
print(f"My name is {name}")
print(f"I am {age} years old.")
print(f"My CGPA is { cgpa}")

# %%
name = input("Enter ur name: ")
age = int(input("Enter age: "))

year = 2026 - age

print(f"{name} was born on {year}.")
# Out:
# Arti was born on 2006.

# %% [markdown]
# Slicing

# %%
name = "Machine"

print(name[0:4])
# Out:
# Mach

# %% [markdown]
# Common Functions

# %%
name.upper()

name.lower()

len(name)

name.replace("A","R")

name.count("a")

name.find("i")
# Out:
# 4

# %%
age = 59

if age>=18 and age<50:
    name=input("Enter Name: ")
    print(name, "you can vote")
elif(age>=50 and age <=100):
    print("u should vote")
else:
    print("you cant vote")
